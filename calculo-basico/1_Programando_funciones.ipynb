# %% [markdown]
# <a href="https://colab.research.google.com/github/AaronGaribay/datacademy2021/blob/main/calculo-basico/1_Programando_funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def element(coeff : float = 1.0, x: np.ndarray = np.linspace(-10.0, 10.0, 100), power: float = 0.0):
    return coeff * (x ** power)

# %%
def first_grade(m: float, x: np.linspace, b: float):
    return element(m, x, 1.0) + b

# %%
def plot_now(x: np.ndarray, y: np.ndarray, color: str = 'b', xlim: list = None, ylim: list = None):
    fig, ax = plt.subplots()
    ax.grid()
    ax.axhline(y=0, color=color)
    ax.axvline(x=0, color=color)
    if not xlim is None: ax.set_xlim(left=xlim[0], right=xlim[1])
    if not ylim is None: ax.set_ylim(bottom=ylim[0], top=ylim[1])
    ax.plot(x,y)

# %%
res = 100
m = 10
b = 5
x = np.linspace(-10.0, 10.0, num=res)
y = f(m, x, b)
plot_now(x, y)

# %%
res = 100
x = np.linspace(-10.0, 10.0, num=res)
y = element(2.0, x, 7.0) + element(-1.0, x, 4.0) + element(3.0, x, 2.0) + 4
plot_now(x, y)

# %%
res = 100
x = np.linspace(-10.0, 10.0, num=res)
y = element(2.0, x, 8.0) + element(-1.0, x, 4.0) + element(3.0, x, 2.0) + 4
plot_now(x, y)
