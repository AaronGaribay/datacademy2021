# %% [markdown]
# <a href="https://colab.research.google.com/github/AaronGaribay/datacademy2021/blob/main/probabilidad/9_Distribucion_normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# ## Distribución normal teórica

# %%
def gaussian(x, mu, sigma):
    left = 1 / (sigma * np.sqrt(2 * np.pi))
    right = np.exp(-0.5 * pow((x - mu)/sigma , 2))
    return left * right

# %%
x = np.arange(-4, 4, 0.1)
y = gaussian(x, 0.0, 1.0)

plt.plot(x, y)

# %%
dist = norm(0, 1)
x = np.arange(-4 ,4, 0.1)
y = [dist.pdf(value) for value in x]
plt.plot(x, y)

# %%
dist = norm(0, 1)
x = np.arange(-4, 4, 0.1)
y = [dist.cdf(value) for value in x]
plt.plot(x, y)

# %% [markdown]
# ## construyendo desde un excel con datos reales
# Longitud de alas de mosquitos domesticos

# %%
df = pd.read_excel('https://seattlecentral.edu/qelp/sets/057/s057.xls')
lengths = df['Normally Distributed Housefly Wing Lengths'].values[4:]
values, dist = np.unique(lengths, return_counts=True)
plt.bar(values, dist)
# Out:
# <BarContainer object of 19 artists>

# %%
# estimacion parametrica
mu = lengths.mean()
sigma = lengths.std()
dist = norm(mu, sigma)
print(sigma)

x = np.arange(30, 60, 0.1)
y = [dist.pdf(value) for value in x]

plt.plot(x, y, color = 'orange')
values, dist = np.unique(lengths, return_counts=True)
plt.bar(values, dist / len(lengths))
# Out:
# 3.8003699764580126
# <BarContainer object of 19 artists>
